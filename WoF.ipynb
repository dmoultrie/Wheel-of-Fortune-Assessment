# %%
import csv
with open('phrases.csv', 'w', newline = '') as csvfile:
    fieldnames = ['category', 'phrase']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerow({'category': '1', 'phrase': 'Birds Of a Feather Flock Together'})
    writer.writerow({'category': '2', 'phrase': 'The Early Bird Gets The Worm'})
    writer.writerow({'category': '3', 'phrase': 'All Bark And No Bite'})
    writer.writerow({'category': '4', 'phrase': 'Curiosity Killed The Cat'})
    writer.writerow({'category': '5', 'phrase': 'Beating a Dead Horse'})
    writer.writerow({'category': '6', 'phrase': 'Bull In a China Shop'})
    writer.writerow({'category': '7', 'phrase': 'Elephant In The Room'})
    writer.writerow({'category': '8', 'phrase': 'Go Down The Rabbit Hole'})
    writer.writerow({'category': '9', 'phrase': 'The Quick Brown Fox Jumps Over The Lazy Dog'})
    writer.writerow({'category': '10', 'phrase': 'Swinging For The Fences'})
    writer.writerow({'category': '11', 'phrase': 'Roll With The Punches'})
    writer.writerow({'category': '12', 'phrase': 'Right Out Of The Gate'})
    writer.writerow({'category': '13', 'phrase': 'Par For The Course'})
    writer.writerow({'category': '14', 'phrase': 'Photo Finish'})
    writer.writerow({'category': '15', 'phrase': 'Down For The Count'})
    writer.writerow({'category': '16', 'phrase': 'Quit Cold Turkey'})
    writer.writerow({'category': '17', 'phrase': 'Not My Cup Of Tea'})
    writer.writerow({'category': '18', 'phrase': 'A Fool and His Money Are Soon Parted'})
    writer.writerow({'category': '19', 'phrase': 'In For a Penny In For a Pound'})
    writer.writerow({'category': '20', 'phrase': 'Nickel and Diming'})
    writer.writerow({'category': '21', 'phrase': 'A Dog Catching A Frisbee'})
    writer.writerow({'category': '22', 'phrase': 'Sphynx Cat'})
    writer.writerow({'category': '23', 'phrase': 'Prairie Chicken'})
    writer.writerow({'category': '24', 'phrase': 'Arctic Fox'})
    writer.writerow({'category': '25', 'phrase': 'Dairy Cow'})
    writer.writerow({'category': '26', 'phrase': 'Black Crow'})
    writer.writerow({'category': '27', 'phrase': 'English Sheepdog'})
    writer.writerow({'category': '28', 'phrase': 'Timber Wolf'})
    writer.writerow({'category': '29', 'phrase': 'Peregrine Falcon'})
    writer.writerow({'category': '30', 'phrase': 'Green And Black Poison Dart Frog'})
    writer.writerow({'category': '31', 'phrase': 'Galloping Horses'})
    writer.writerow({'category': '32', 'phrase': 'Diamondback Rattlesnake'})
    writer.writerow({'category': '33', 'phrase': 'Bull Moose'})
    writer.writerow({'category': '34', 'phrase': 'Cherry Blossom Tree'})
    writer.writerow({'category': '35', 'phrase': 'Towering Oak Trees'})
    writer.writerow({'category': '36', 'phrase': 'Daffodil'})
    writer.writerow({'category': '37', 'phrase': 'Periwinkle'})
    writer.writerow({'category': '38', 'phrase': 'Pygmy Sperm Whale'})
    writer.writerow({'category': '39', 'phrase': 'Horseshoe Crab'})
    writer.writerow({'category': '40', 'phrase': 'Grizzly Bear'})
    writer.writerow({'category': '41', 'phrase': 'Aerospace Engineer'})
    writer.writerow({'category': '42', 'phrase': 'Anthropologist'})
    writer.writerow({'category': '43', 'phrase': 'Sleep Doctor'})
    writer.writerow({'category': '44', 'phrase': 'College Professor'})
    writer.writerow({'category': '45', 'phrase': 'Professional Swimmer'})
    writer.writerow({'category': '46', 'phrase': 'Fire Marshal'})
    writer.writerow({'category': '47', 'phrase': 'Underwater Filmmaker'})
    writer.writerow({'category': '48', 'phrase': 'Dairy Farmer'})
    writer.writerow({'category': '49', 'phrase': 'Chief Financial Officer'})
    writer.writerow({'category': '50', 'phrase': 'Payroll Accountant'})
    writer.writerow({'category': '51', 'phrase': 'Freelance Journalist'})
    writer.writerow({'category': '52', 'phrase': 'Campaign Manager'})
    writer.writerow({'category': '53', 'phrase': 'Pastry Chef'})
    writer.writerow({'category': '54', 'phrase': 'Astrophysicist'})
    writer.writerow({'category': '55', 'phrase': 'Gymnastics Coach'})
    writer.writerow({'category': '56', 'phrase': 'Professional Taster'})
    writer.writerow({'category': '57', 'phrase': 'Childrens Book Author'})
    writer.writerow({'category': '58', 'phrase': 'Cycling Instructor'})
    writer.writerow({'category': '59', 'phrase': 'Homicide Detective'})
    writer.writerow({'category': '60', 'phrase': 'Personal Assistant'})

# %%
wheeltile = [
    100,
    100,
    150,
    150,
    200,
    200,
    250,
    250,
    300,
    300,
    350,
    400,
    450,
    500,
    550,
    600,
    650,
    700,
    750,
    800,
    850,
    900,
    "bankrupt",
    "lose a turn"
]
import csv
import random 

def spinwheel():
    return (random.choice(list(wheeltile)))


def CatchPhraseR1():
    with open("phrases.csv", newline='') as csvfile:
        reader1 = csv.DictReader(csvfile)
        readerlist1 = list(reader1)
        category1 = random.choice(list(range(21,41)))
        phrasedict1 = readerlist1[category1 - 1]
        phrase1 = phrasedict1["phrase"]
        return(phrase1.lower())


def CatchPhraseR2():
    with open("phrases.csv", newline='') as csvfile:
        reader2 = csv.DictReader(csvfile)
        readerlist2 = list(reader2)
        category2 = random.choice(list(range(41,61)))
        phrasedict2 = readerlist2[category2 - 1]
        phrase2 = phrasedict2["phrase"]
        return(phrase2.lower())


def CatchPhraseFR():
    with open("phrases.csv", newline='') as csvfile:
        reader3 = csv.DictReader(csvfile)
        readerlist3 = list(reader3)
        category3 = random.choice(list(range(1,21)))
        phrasedict3 = readerlist3[category3 - 1]
        phrase3 = phrasedict3["phrase"]
        return(phrase3.lower())


def HiddenPhrase1(phrase1, guessed1):
    rv1 = ''
    for s in phrase1:
        if (s in letters) and (s not in guessed1):
            rv1 += '_'
        else:
            rv1 += s
    return(rv1)

def HiddenPhrase2(phrase2, guessed2):
    rv2 = ''
    for s in phrase2:
        if (s in letters) and (s not in guessed2):
            rv2 += '_'
        else:
            rv2 += s
    return(rv2)

def HiddenPhraseFR(phrase3, guessed3):
    rv3 = ''
    for s in phrase3:
        if (s in lettersf) and (s not in guessed3):
            rv3 += '_'
        else:
            rv3 += s
    return(rv3)

print('-'*15)
print('Welcome to Wheel of Fortune')
print('-'*15)
print('')

letters = 'abcdefghijklmnopqrstuvwxyz'
lettersf = 'abcdfghijkmopquvwxyz'
vowels  = 'aeiou'
vowelcost  = 250
category1 = 'living things'
category2 = 'occupation'
category3 = 'phrase'
phrase1 = CatchPhraseR1()
phrase2 = CatchPhraseR2()
phrase3 = CatchPhraseFR()
guessed1 = []
guessed2 = []
guessed3 = []
playernumber = random.choice(range(0,2))
winner1 = False
winner2 = False
winnerFR = False

player1 = input('Enter the name for player #1 ')
bank1 = 0
r1bank1 = 0
r2bank1 = 0
def bankrupt1():
    r1bank1 = 0
    r2bank1 = 0

player2 = input('Enter the name for player #2 ')
bank2 = 0
r1bank2 = 0
r2bank2 = 0
def bankrupt2():
    r1bank2 = 0
    r2bank2 = 0

player3 = input('Enter the name for player #3 ')
bank3 = 0
r1bank3 = 0
r2bank3 = 0
def bankrupt3():
    r1bank3 = 0
    r2bank3 = 0

def RequestPlayerMoveR1P1(player1, category1, guessed1):
    while True: 
        mover1p1 = input("{} the category is {}, {} has been guessed and you have ${} for the round. Here's the remaining board:\n\n{}\n\n Guess a letter or try to solve: ".format(player1,category1,guessed1,r1bank1,HiddenPhrase1(phrase1, guessed1)))
        mover1p1 = mover1p1.lower()
        if len(mover1p1) == 1:
            if mover1p1 not in letters:
                print('Guesses should be letters. Try again.')
                continue
            elif mover1p1 in guessed1:
                print('{} has already been guessed. Try again.'.format(mover1p1))
                continue
            elif mover1p1 in vowels and r1bank1 < vowelcost:
                    print('Need ${} to guess a vowel. Try again.'.format(vowelcost))
                    continue
            else:
                return mover1p1
        else:
            return mover1p1

def RequestPlayerMoveR2P1(player1, category2, guessed2):
    while True: 
        mover2p1 = input("{} the category is {}, {} has been guessed and you have ${} for the round. Here's the remaining board:\n\n{}\n\n Guess a letter or try to solve: ".format(player1,category2,guessed2,r2bank1,HiddenPhrase2(phrase2, guessed2)))
        mover2p1 = mover2p1.lower()
        if len(mover2p1) == 1:
            if mover2p1 not in letters:
                print('Guesses should be letters. Try again.')
                continue
            elif mover2p1 in guessed2:
                print('{} has already been guessed. Try again.'.format(mover2p1))
                continue
            elif mover2p1 in vowels and r2bank1 < vowelcost:
                    print('Need ${} to guess a vowel. Try again.'.format(vowelcost))
                    continue
            else:
                return mover2p1
        else:
            return mover2p1
    
def RequestPlayerMoveR1P2(player2, category1, guessed1):
    while True: 
        mover1p2 = input("{} the category is {}, {} has been guessed and you have ${} for the round. Here's the remaining board:\n\n{}\n\n Guess a letter or try to solve: ".format(player2,category1,guessed1,r1bank2,HiddenPhrase1(phrase1, guessed1)))
        mover1p2 = mover1p2.lower()
        if len(mover1p2) == 1:
            if mover1p2 not in letters:
                print('Guesses should be letters. Try again.')
                continue
            elif mover1p2 in guessed1:
                print('{} has already been guessed. Try again.'.format(mover1p2))
                continue
            elif mover1p2 in vowels and r1bank2 < vowelcost:
                    print('Need ${} to guess a vowel. Try again.'.format(vowelcost))
                    continue
            else:
                return mover1p2
        else:
            return mover1p2

def RequestPlayerMoveR2P2(player2, category2, guessed2):
    while True: 
        mover2p2 = input("{} the category is {}, {} has been guessed and you have ${} for the round. Here's the remaining board:\n\n{}\n\n Guess a letter or try to solve: ".format(player2,category2,guessed2,r2bank2,HiddenPhrase2(phrase2, guessed2)))
        mover2p2 = mover2p2.lower()
        if len(mover2p2) == 1:
            if mover2p2 not in letters:
                print('Guesses should be letters. Try again.')
                continue
            elif mover2p2 in guessed2:
                print('{} has already been guessed. Try again.'.format(mover2p2))
                continue
            elif mover2p2 in vowels and r2bank2 < vowelcost:
                    print('Need ${} to guess a vowel. Try again.'.format(vowelcost))
                    continue
            else:
                return mover2p2
        else:
            return mover2p2

def RequestPlayerMoveR1P3(player3, category1, guessed1):
    while True: 
        mover1p3 = input("{} the category is {}, {} has been guessed and you have ${} for the round. Here's the remaining board:\n\n{}\n\n Guess a letter or try to solve: ".format(player3,category1,guessed1,r1bank3,HiddenPhrase1(phrase1, guessed1)))
        mover1p3 = mover1p3.lower()
        if len(mover1p3) == 1:
            if mover1p3 not in letters:
                print('Guesses should be letters. Try again.')
                continue
            elif mover1p3 in guessed1:
                print('{} has already been guessed. Try again.'.format(mover1p3))
                continue
            elif mover1p3 in vowels and r1bank3 < vowelcost:
                    print('Need ${} to guess a vowel. Try again.'.format(vowelcost))
                    continue
            else:
                return mover1p3
        else:
            return mover1p3
        
def RequestPlayerMoveR2P3(player3, category2, guessed2):
    while True: 
        mover2p3 = input("{} the category is {}, {} has been guessed and you have ${} for the round. Here's the remaining board:\n\n{}\n\n Guess a letter or try to solve: ".format(player3,category2,guessed2,r2bank3,HiddenPhrase2(phrase2, guessed2)))
        mover2p3 = mover2p3.lower()
        if len(mover2p3) == 1:
            if mover2p3 not in letters:
                print('Guesses should be letters. Try again.')
                continue
            elif mover2p3 in guessed2:
                print('{} has already been guessed. Try again.'.format(mover2p3))
                continue
            elif mover2p3 in vowels and r2bank3 < vowelcost:
                    print('Need ${} to guess a vowel. Try again.'.format(vowelcost))
                    continue
            else:
                return mover2p3
        else:
            return mover2p3

def RequestPlayerMoveFRP1(player1, category3, guessed3):
    while True: 
        mover3p1 = input("{} the category is {}, {} has been guessed. Here's the remaining board:\n\n{}\n\n Guess a consonant: ".format(player1,category3,guessed3,HiddenPhraseFR(phrase3, guessed3)))
        mover3p1 = mover3p1.lower()
        if len(mover3p1) == 1:
            if mover3p1 not in lettersf:
                print('Guesses should be letters. Try again.')
                continue
            elif mover3p1 in guessed3:
                print('{} has already been guessed. Try again.'.format(mover3p1))
                continue
            else:
                return mover3p1
        else:
            return mover3p1
    
def RequestPlayerMoveFRP2(player2, category3, guessed3):
    while True: 
        mover3p2 = input("{} the category is {}, {} has been guessed. Here's the remaining board:\n\n{}\n\n Guess a consonant: ".format(player2,category3,guessed3,HiddenPhraseFR(phrase3, guessed3)))
        mover3p2 = mover3p2.lower()
        if len(mover3p2) == 1:
            if mover3p2 not in lettersf:
                print('Guesses should be letters. Try again.')
                continue
            elif mover3p2 in guessed3:
                print('{} has already been guessed. Try again.'.format(mover3p2))
                continue
            else:
                return mover3p2
        else:
            return mover3p2
    
def RequestPlayerMoveFRP3(player3, category3, guessed3):
    while True: 
        mover3p3 = input("{} the category is {}, {} has been guessed. Here's the remaining board:\n\n{}\n\n Guess a consonant: ".format(player3,category3,guessed3,HiddenPhraseFR(phrase3, guessed3)))
        mover3p3 = mover3p3.lower()
        if len(mover3p3) == 1:
            if mover3p3 not in lettersf:
                print('Guesses should be letters. Try again.')
                continue
            elif mover3p3 in guessed3:
                print('{} has already been guessed. Try again.'.format(mover3p3))
                continue
            else:
                return mover3p3
        else:
            return mover3p3    
    
print("Let's begin Round 1!")
while True:
    player = playernumber
    tile = spinwheel()
    if player == 0:
        print('{} spins...'.format(player1))
        print('{}!'.format(tile))
        if tile == 'bankrupt':
            bankrupt1()
        elif tile == 'lose a turn':
            pass
        else:
            mover1p1 = RequestPlayerMoveR1P1(player1, category1, guessed1)
            if len(mover1p1) == 1:
                guessed1.append(mover1p1)

                print('{} guesses "{}"'.format(player1, mover1p1))

                if mover1p1 in vowels:
                    r1bank1 -= vowelcost

                count = phrase1.count(mover1p1)
                if count > 0:
                    if count == 1:
                        print("There is one {}".format(mover1p1))
                    else:
                        print("There are {} {}'s".format(count, mover1p1))

                    if mover1p1 in vowels:
                        pass
                    else:
                        r1bank1 += (count * tile)
                    
                    solve = input("If you would like to solve the puzzle, enter your guess here. If not, enter'no'\n")
                    if solve == "no":
                        pass
                    else:
                        if solve == phrase1:
                            winner1 = player1
                            bank1 += r1bank1
                            print("Correct! The answer is {}".format(solve))
                            break
                        else:
                            print("{} was not the phrase".format(solve))
                    
                    if HiddenPhrase1(phrase1, guessed1) == phrase1:
                        winner1 = player1
                        bank1 += r1bank1
                        print("The answer is {}. Good job!".format(phrase1))
                        break

                    continue 

                elif count == 0:
                    print("There is no {}".format(mover1p1))
            else: 
                if mover1p1 == phrase1: 
                    winner1 = player1
                    bank1 += r1bank1
                    print("Correct! The answer is {}".format(mover1p1))
                    break
                else:
                    print('{} was not the phrase'.format(mover1p1))

        playernumber = (playernumber + 1) % 3
    elif player == 1:
        print('{} spins...'.format(player2))
        print('{}!'.format(tile))
        if tile == 'bankrupt':
            bankrupt2()
        elif tile == 'lose a turn':
            pass 
        else:
            mover1p2 = RequestPlayerMoveR1P2(player2, category1, guessed1)
            if len(mover1p2) == 1:
                guessed1.append(mover1p2)

                print('{} guesses "{}"'.format(player2, mover1p2))

                if mover1p2 in vowels:
                    r1bank2 -= vowelcost

                count = phrase1.count(mover1p2)
                if count > 0:
                    if count == 1:
                        print("There is one {}".format(mover1p2))
                    else:
                        print("There are {} {}'s".format(count, mover1p2))

                    if mover1p2 in vowels:
                        pass
                    else:
                        r1bank2 += (count * tile)
                    
                    solve = input("If you would like to solve the puzzle, enter your guess here. If not, enter'no'\n")
                    if solve == "no":
                        pass
                    else:
                        if solve == phrase1:
                            winner1 = player2
                            bank2 += r1bank2
                            print("Correct! The answer is {}".format(solve))
                            break
                        else:
                            print("{} was not the phrase".format(solve))
                                                
                    if HiddenPhrase1(phrase1, guessed1) == phrase1:
                        winner1 = player2
                        bank2 += r1bank2
                        print("The answer is {}. Good job!".format(phrase1))
                        break

                    continue 

                elif count == 0:
                    print("There is no {}".format(mover1p2))
            else: 
                if mover1p2 == phrase1: 
                    winner1 = player2
                    bank2 += r1bank2
                    print("Correct! The answer is {}".format(mover1p2))
                    break
                else:
                    print('{} was not the phrase'.format(mover1p2))

        playernumber = (playernumber + 1) % 3
    elif player == 2:
        print('{} spins...'.format(player3))
        print('{}!'.format(tile))
        if tile == 'bankrupt':
            bankrupt3()
        elif tile == 'lose a turn':
            pass 
        else:
            mover1p3 = RequestPlayerMoveR1P3(player3, category1, guessed1)
            if len(mover1p3) == 1:
                guessed1.append(mover1p3)

                print('{} guesses "{}"'.format(player3, mover1p3))

                if mover1p3 in vowels:
                    r1bank3 -= vowelcost

                count = phrase1.count(mover1p3)
                if count > 0:
                    if count == 1:
                        print("There is one {}".format(mover1p3))
                    else:
                        print("There are {} {}'s".format(count, mover1p3))

                    if mover1p3 in vowels:
                        pass
                    else:
                        r1bank3 += (count * tile)
                    
                    solve = input("If you would like to solve the puzzle, enter your guess here. If not, enter'no'\n")
                    if solve == "no":
                        pass
                    else:
                        if solve == phrase1:
                            winner1 = player3
                            bank3 += r1bank3
                            print("Correct! The answer is {}".format(solve))
                            break
                        else:
                            print("{} was not the phrase".format(solve))
                                                
                    if HiddenPhrase1(phrase1, guessed1) == phrase1:
                        winner1 = player3
                        bank3 += r1bank3
                        print("The answer is {}. Good job!".format(phrase1))
                        break

                    continue 

                elif count == 0:
                    print("There is no {}".format(mover1p3))
            else: 
                if mover1p3 == phrase1: 
                    winner1 = player3
                    bank3 += r1bank3
                    print("Correct! The answer is {}".format(mover1p3))
                    break
                else:
                    print('{} was not the phrase'.format(mover1p3))

        playernumber = (playernumber + 1) % 3

print("\n{} has ${}".format(player1,bank1))
print("{} has ${}".format(player2,bank2))
print("{} has ${}".format(player3,bank3))
playernumber = (playernumber + 1) % 3
print("Let's begin Round 2!")
while True:
    player = playernumber
    tile = spinwheel()
    if player == 0:
        print('{} spins...'.format(player1))
        print('{}!'.format(tile))
        if tile == 'bankrupt':
            bankrupt1()
        elif tile == 'lose a turn':
            pass
        else:
            mover2p1 = RequestPlayerMoveR2P1(player1, category2, guessed2)
            if len(mover2p1) == 1:
                guessed2.append(mover2p1)

                print('{} guesses "{}"'.format(player1, mover2p1))

                if mover2p1 in vowels:
                    r2bank1 -= vowelcost

                count = phrase2.count(mover2p1)
                if count > 0:
                    if count == 1:
                        print("There is one {}".format(mover2p1))
                    else:
                        print("There are {} {}'s".format(count, mover2p1))

                    if mover2p1 in vowels:
                        pass
                    else:
                        r2bank1 += (count * tile)
                    
                    solve = input("If you would like to solve the puzzle, enter your guess here. If not, enter'no'\n")
                    if solve == "no":
                        pass
                    else:
                        if solve == phrase2:
                            winner2 = player1
                            bank1 += r2bank1
                            print("Correct! The answer is {}".format(solve))
                            break
                        else:
                            print("{} was not the phrase".format(solve))
                    
                    if HiddenPhrase2(phrase2, guessed2) == phrase2:
                        winner2 = player1
                        bank1 += r2bank1
                        print("The answer is {}. Good job!".format(phrase2))
                        break

                    continue 

                elif count == 0:
                    print("There is no {}".format(mover2p1))
            else: 
                if mover2p1 == phrase2: 
                    winner2 = player1
                    bank1 += r2bank1
                    print("Correct! The answer is {}".format(mover2p1))
                    break
                else:
                    print('{} was not the phrase'.format(mover2p1))

        playernumber = (playernumber + 1) % 3
    elif player == 1:
        print('{} spins...'.format(player2))
        print('{}!'.format(tile))
        if tile == 'bankrupt':
            bankrupt2()
        elif tile == 'lose a turn':
            pass 
        else:
            mover2p2 = RequestPlayerMoveR2P2(player2, category2, guessed2)
            if len(mover2p2) == 1:
                guessed2.append(mover2p2)

                print('{} guesses "{}"'.format(player2, mover2p2))

                if mover2p2 in vowels:
                    r2bank2 -= vowelcost

                count = phrase2.count(mover2p2)
                if count > 0:
                    if count == 1:
                        print("There is one {}".format(mover2p2))
                    else:
                        print("There are {} {}'s".format(count, mover2p2))

                    if mover2p2 in vowels:
                        pass
                    else:
                        r2bank2 += (count * tile)
                    
                    solve = input("If you would like to solve the puzzle, enter your guess here. If not, enter'no'\n")
                    if solve == "no":
                        pass
                    else:
                        if solve == phrase2:
                            winner2 = player2
                            bank2 += r2bank2
                            print("Correct! The answer is {}".format(solve))
                            break
                        else:
                            print("{} was not the phrase".format(solve))
                                                
                    if HiddenPhrase2(phrase2, guessed2) == phrase2:
                        winner2 = player2
                        bank2 += r2bank2
                        print("The answer is {}. Good job!".format(phrase2))
                        break

                    continue 

                elif count == 0:
                    print("There is no {}".format(mover2p2))
            else: 
                if mover2p2 == phrase2: 
                    winner2 = player2
                    bank2 += r2bank2
                    print("Correct! The answer is {}".format(mover2p2))
                    break
                else:
                    print('{} was not the phrase'.format(mover2p2))

        playernumber = (playernumber + 1) % 3
    elif player == 2:
        print('{} spins...'.format(player3))
        print('{}!'.format(tile))
        if tile == 'bankrupt':
            bankrupt3()
        elif tile == 'lose a turn':
            pass 
        else:
            mover2p3 = RequestPlayerMoveR2P3(player3, category2, guessed2)
            if len(mover2p3) == 1:
                guessed2.append(mover2p3)

                print('{} guesses "{}"'.format(player3, mover2p3))

                if mover2p3 in vowels:
                    r2bank3 -= vowelcost

                count = phrase2.count(mover2p3)
                if count > 0:
                    if count == 1:
                        print("There is one {}".format(mover2p3))
                    else:
                        print("There are {} {}'s".format(count, mover2p3))

                    if mover2p3 in vowels:
                        pass
                    else:
                        r2bank3 += (count * tile)
                    
                    solve = input("If you would like to solve the puzzle, enter your guess here. If not, enter'no'\n")
                    if solve == "no":
                        pass
                    else:
                        if solve == phrase2:
                            winner2 = player3
                            bank3 += r2bank3
                            print("Correct! The answer is {}".format(solve))
                            break
                        else:
                            print("{} was not the phrase".format(solve))
                                                
                    if HiddenPhrase2(phrase2, guessed2) == phrase2:
                        winner2 = player3
                        bank3 += r2bank3
                        print("The answer is {}. Good job!".format(phrase2))
                        break

                    continue 

                elif count == 0:
                    print("There is no {}".format(mover2p3))
            else: 
                if mover2p3 == phrase2: 
                    winner2 = player3
                    bank3 += r2bank3
                    print("Correct! The answer is {}".format(mover2p3))
                    break
                else:
                    print('{} was not the phrase'.format(mover2p3))

        playernumber = (playernumber + 1) % 3
    
print("\n{} has ${}".format(player1,bank1))
print("{} has ${}".format(player2,bank2))
print("{} has ${}".format(player3,bank3))
if max(bank1, bank2, bank3) == bank1:
    print("{}, you have made it to the final round!".format(player1))
    while True:
        mover3p1 = RequestPlayerMoveFRP1(player1, category3, guessed3)
        if len(mover3p1) == 1:
            guessed3.append(mover3p1)
            print('{} guesses "{}"'.format(player1, mover3p1))
            count = phrase3.count(mover3p1)
            if count > 0:
                if count == 1:
                    print("There is one {}".format(mover3p1))
                else:
                    print("There are {} {}'s".format(count, mover3p1))
            elif count == 0:
                print("There is no {}".format(mover3p1))
        else:
            continue
        mover3p1v = input("\nEnter a vowel: ")
        if len(mover3p1v) == 1:
            guessed3.append(mover3p1v)
            print('{} guesses "{}"'.format(player1, mover3p1v))
            count = phrase3.count(mover3p1v)
            if count > 0:
                if count == 1:
                    print("There is one {}".format(mover3p1v))
                else:
                    print("There are {} {}'s".format(count, mover3p1v))
            elif count == 0:
                print("There is no {}".format(mover3p1v))
        else:
            continue
        mover3p1g = input("What is the phrase? Enter your guess: ")
        if mover3p1g == phrase3:
            winner3 = player1
            bank1 += 25000
            print("Correct! The answer is {}\nWith that, you have won the $25000 grand pize bringing your overall winnings to \n{}!".format(mover3p1g,bank1))
        else:
            print('Sorry, {} was not the phrase.\nThe correct answer was {}.\nBut at least you still walk away with {}. Feel free to try again!'.format(mover3p1g,phrase3,bank1))
elif max(bank1, bank2, bank3) == bank2:
    print("{}, you have made it to the final round!".format(player2))
    while True:
        mover3p2,mover3p2v,mover3p2g = RequestPlayerMoveFRP2(player2, category3, guessed3)
        if len(mover3p2) == 1:
            guessed3.append(mover3p2)
            print('{} guesses "{}"'.format(player2, mover3p2))
            count = phrase3.count(mover3p2)
            if count > 0:
                if count == 1:
                    print("There is one {}".format(mover3p2))
                else:
                    print("There are {} {}'s".format(count, mover3p2))
            elif count == 0:
                print("There is no {}".format(mover3p2))
        else:
            continue
        mover3p2v = input("\nEnter a vowel: ")
        if len(mover3p2v) == 1:
            guessed3.append(mover3p2v)
            print('{} guesses "{}"'.format(player1, mover3p2v))
            count = phrase3.count(mover3p2v)
            if count > 0:
                if count == 1:
                    print("There is one {}".format(mover3p2v))
                else:
                    print("There are {} {}'s".format(count, mover3p2v))
            elif count == 0:
                print("There is no {}".format(mover3p2v))
        else:
            continue
        mover3p2g = input("What is the phrase? Enter your guess: ")
        if mover3p2g == phrase3:
            winner3 = player2
            bank2 += 25000
            print("Correct! The answer is {}\nWith that, you have won the $25000 grand pize bringing your overall winnings to \n{}!".format(mover3p2g,bank2))
        else:
            print('Sorry, {} was not the phrase.\nThe correct answer was {}.\nBut at least you still walk away with {}. Feel free to try again!'.format(mover3p2g,phrase3,bank2))
elif max(bank1, bank2, bank3) == bank3:
    print("{}, you have made it to the final round!".format(player3))
    while True:
        mover3p3,mover3p3v,mover3p3g = RequestPlayerMoveFRP3(player3, category3, guessed3)
        if len(mover3p3) == 1:
            guessed3.append(mover3p3)
            print('{} guesses "{}"'.format(player3, mover3p3))
            count = phrase3.count(mover3p3)
            if count > 0:
                if count == 1:
                    print("There is one {}".format(mover3p3))
                else:
                    print("There are {} {}'s".format(count, mover3p3))
            elif count == 0:
                print("There is no {}".format(mover3p3))
        else:
            continue
        mover3p3v = input("\nEnter a vowel: ")        
        if len(mover3p3v) == 1:
            guessed3.append(mover3p3v)
            print('{} guesses "{}"'.format(player3, mover3p3v))
            count = phrase3.count(mover3p3v)
            if count > 0:
                if count == 1:
                    print("There is one {}".format(mover3p3v))
                else:
                    print("There are {} {}'s".format(count, mover3p3v))
            elif count == 0:
                print("There is no {}".format(mover3p3v))
        else:
            continue
        mover3p3g = input("What is the phrase? Enter your guess: ")
        if mover3p3g == phrase3:
            winner3 = player3
            bank3 += 25000
            print("Correct! The answer is {}\nWith that, you have won the $25000 grand pize bringing your overall winnings to \n{}!".format(mover3p1g,bank3))
        else:
            print('Sorry, {} was not the phrase.\nThe correct answer was {}.\nBut at least you still walk away with {}. Feel free to try again!'.format(mover3p1g,phrase3,bank3))
# Out:
# ---------------
# Welcome to Wheel of Fortune
# ---------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-032f1fb0564b> in <module>
#     112 winnerFR = False
#     113
# --> 114 player1 = input('Enter the name for player #1 ')
#     115 bank1 = 0
#     116 r1bank1 = 0
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
